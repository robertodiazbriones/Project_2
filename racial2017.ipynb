# %%
import pandas as pd

df = pd.read_csv('combined_csv.csv')
df.head()
# Out:
#   Lea State                           LEA School State  \
# 0        MI       Berkley School District           MI
# 1        MI       Berkley School District           MI
# 2        MI       Berkley School District           MI
# 3        MI  Grosse Pointe Public Schools           MI
# 4        MI  Grosse Pointe Public Schools           MI
#
#                             School            ID  Year  \
# 0              Berkley High School  2.605010e+11  2017
# 1              Berkley High School  2.605010e+11  2017
# 2              Berkley High School  2.605010e+11  2017
# 3  Grosse Pointe North High School  2.625740e+11  2017
# 4  Grosse Pointe North High School  2.625740e+11  2017
#
#                                             Category  \
# 0                           Enrollment in AP classes
# 1          Taking AP tests for some AP courses taken
# 2  Students who took AP courses but did not take ...
# 3                           Enrollment in AP classes
# ...

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# Length: 261, dtype: bool

# %%
df.drop(columns=['ID', 'Category'])
# Out:
#     Lea State                                     LEA School State  \
# 0          MI                 Berkley School District           MI
# 1          MI                 Berkley School District           MI
# 2          MI                 Berkley School District           MI
# 3          MI            Grosse Pointe Public Schools           MI
# 4          MI            Grosse Pointe Public Schools           MI
# ..        ...                                     ...          ...
# 256        MI  Livonia Public Schools School District           MI
# 257        MI  Livonia Public Schools School District           MI
# 258        MI  Livonia Public Schools School District           MI
# 259        MI  Livonia Public Schools School District           MI
# 260        MI  Livonia Public Schools School District           MI
#
#                               School  Year  American Indian or Alaska Native  \
# 0                Berkley High School  2017                               1.0
# ...
