# %%
import pandas as pd

# %%
df = pd.read_csv('RacialCensus_2019.csv')
df.head()
# Out:
#    District Code                     District Name  American Indian  \
# 0           1010          Alcona Community Schools                3
# 1           2010      AuTrain-Onota Public Schools                1
# 2           2020     Burt Township School District                3
# 3           2070           Munising Public Schools              103
# 4           2080  Superior Central School District               34
#
#   AI_Percent  Asian / Pacific AP_Percent  African American AA_Percent  \
# 0      0.44%                2      0.29%                 6      0.88%
# 1      2.63%                0      0.00%                 0      0.00%
# 2      9.09%                1      3.03%                 0      0.00%
# 3     15.68%                4      0.61%                 6      0.91%
# 4     10.15%                3      0.90%                 5      1.49%
#
#    Hispanic H_Percent  White White Percent  Multiracial Multiracial Percent  \
# ...

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.drop(columns=['Unnamed: 16', 'Unnamed: 17'])
# Out:
#      District Code                          District Name  American Indian  \
# 0             1010               Alcona Community Schools                3
# 1             2010           AuTrain-Onota Public Schools                1
# 2             2020          Burt Township School District                3
# 3             2070                Munising Public Schools              103
# 4             2080       Superior Central School District               34
# ..             ...                                    ...              ...
# 886          83060            Manton Consolidated Schools                5
# 887          83070            Mesick Consolidated Schools                7
# 888          83900  Highpoint Virtual Academy of Michigan                9
# 889          84010  Michigan Department of Human Services                1
# 890          84020     Michigan Department of Corrections                1
#
# ...
