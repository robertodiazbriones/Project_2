# %%
#import dependancies
import pandas as pd
import numpy as np
from flask import Flask, render_template, redirect
from pprint import pprint

full_df = pd.read_csv('desktop/p_2_data/district_data_full_clean.csv')

full_df.head()
# Out:
#                                      NAME  TOTALREV  TFEDREV  TSTREV  TLOCREV  \
# 0          Adams Township School District      4927      268    3442     1217
# 1               Addison Community Schools     10189     1130    4035     5024
# 2  Adrian, School District of the City of     37526     6400   21662     9464
# 3               Airport Community Schools     27360     1257   18938     7165
# 4                 Akron-Fairgrove Schools      3993      296    1587     2110
#
#    tot_rev_per_s  fed_rev_per_s  st_rev_per_s  loc_rev_per_s  ENROLL  ...  \
# 0      10.876380       0.591611      7.598234       2.686534     453  ...
# 1      11.916959       1.321637      4.719298       5.876023     855  ...
# 2      12.664867       2.159973      7.310834       3.194060    2963  ...
# 3      11.072440       0.508701      7.664104       2.899636    2471  ...
# 4      14.159574       1.049645      5.627660       7.482270     282  ...
#
#    ave_school_enrol  ave_prcnt_wht  ave_prcnt_bk  ave_prcnt_hisp  \
# 0             223.0           98.0           0.5             0.5
# 1             220.5           88.0           1.0             6.5
# 2             431.6           58.2           4.0            29.4
# 3             246.8           91.8           3.2             3.8
# 4             143.5           88.5           0.5             7.5
#
#    ave_prcnt_asn  ave_prcnt_othr  free_lunch_eligible  not_eligible  \
# 0            0.0             1.0                 87.0         106.0
# 1            0.5             4.5                 98.5         108.5
# 2            1.2             7.4                257.4         156.0
# 3            0.4             0.6                125.8         122.4
# 4            0.5             3.0                 93.0          38.0
#
#    total_count  percent_student_body_eligible_for_frl
# 0        228.0                                   53.5
# 1        223.5                                   51.5
# 2        445.4                                   70.4
# 3        261.8                                   56.2
# 4        145.5                                   74.0
#
# [5 rows x 26 columns]

# %%
#full df, prune some rows that probably aren't necessary

prune_df = full_df.drop(columns = ['TOTALREV', 'TFEDREV', 'TSTREV', 'TLOCREV', 'TCURINST', 'TOTALEXP'])

prune_df.head()
# Out:
#                                      NAME  tot_rev_per_s  fed_rev_per_s  \
# 0          Adams Township School District      10.876380       0.591611
# 1               Addison Community Schools      11.916959       1.321637
# 2  Adrian, School District of the City of      12.664867       2.159973
# 3               Airport Community Schools      11.072440       0.508701
# 4                 Akron-Fairgrove Schools      14.159574       1.049645
#
#    st_rev_per_s  loc_rev_per_s  ENROLL  tot_spend_per_s  tot_inst_per_s  \
# 0      7.598234       2.686534     453        10.154525        5.121413
# 1      4.719298       5.876023     855        11.045614        6.376608
# 2      7.310834       3.194060    2963        12.099224        6.657104
# 3      7.664104       2.899636    2471        10.782679        5.854310
# 4      5.627660       7.482270     282        19.244681        6.301418
#
#          lat        lng  ave_school_enrol  ave_prcnt_wht  ave_prcnt_bk  \
# 0  47.055234 -88.658298             223.0           98.0           0.5
# 1  41.988254 -84.343413             220.5           88.0           1.0
# 2  41.895706 -84.049822             431.6           58.2           4.0
# 3  42.041265 -83.338547             246.8           91.8           3.2
# 4  43.556976 -83.529938             143.5           88.5           0.5
#
#    ave_prcnt_hisp  ave_prcnt_asn  ave_prcnt_othr  free_lunch_eligible  \
# 0             0.5            0.0             1.0                 87.0
# 1             6.5            0.5             4.5                 98.5
# 2            29.4            1.2             7.4                257.4
# 3             3.8            0.4             0.6                125.8
# 4             7.5            0.5             3.0                 93.0
#
#    not_eligible  total_count  percent_student_body_eligible_for_frl
# 0         106.0        228.0                                   53.5
# 1         108.5        223.5                                   51.5
# 2         156.0        445.4                                   70.4
# 3         122.4        261.8                                   56.2
# 4          38.0        145.5                                   74.0

# %%
#use a for loop to package the data up

#break prune_df into single component numpy arrays
district = prune_df['NAME'].to_numpy()
lat = prune_df['lat'].to_numpy()
lng = prune_df['lng'].to_numpy()
tot_rev_per_s = prune_df['tot_rev_per_s'].to_numpy()
fed_rev_per_s = prune_df['fed_rev_per_s'].to_numpy()
st_rev_per_s = prune_df['st_rev_per_s'].to_numpy()
loc_rev_per_s = prune_df['loc_rev_per_s'].to_numpy()
district_enrollment = prune_df['ENROLL'].to_numpy()
tot_spend_per_s = prune_df['tot_spend_per_s'].to_numpy()
tot_inst_per_s = prune_df['tot_inst_per_s'].to_numpy()
ave_school_enrol = prune_df['ave_school_enrol'].to_numpy()
ave_prcnt_wht = prune_df['ave_prcnt_wht'].to_numpy()
ave_prcnt_bk = prune_df['ave_prcnt_bk'].to_numpy()
ave_prcnt_asn = prune_df['ave_prcnt_asn'].to_numpy()
ave_prcnt_othr = prune_df['ave_prcnt_othr'].to_numpy()
prcnt_stdnts_eligible_for_frl  = prune_df['percent_student_body_eligible_for_frl'].to_numpy()


#define an empty list for 
dist_data = []

for d in range(len(district)):
    #initialize the dictionary "entry"
    entry = {}
    
    #add all the things
    entry.update({'district': district[d]})
    entry.update({'lat': lat[d]})
    entry.update({'lng': lng[d]})
    entry.update({'tot_rev_per_s': tot_rev_per_s[d]})
    entry.update({'fed_rev_per_s': fed_rev_per_s[d]})
    entry.update({'st_rev_per_s': st_rev_per_s[d]})
    entry.update({'loc_rev_per_s': loc_rev_per_s[d]})
    entry.update({'district_enrollment': district_enrollment[d]})
    entry.update({'tot_spend_per_s': tot_spend_per_s[d]})
    entry.update({'tot_inst_per_s': tot_inst_per_s[d]})
    entry.update({'ave_school_enrol': ave_school_enrol[d]})
    entry.update({'ave_prcnt_wht': ave_prcnt_wht[d]})
    entry.update({'ave_prcnt_bk': ave_prcnt_bk[d]})
    entry.update({'ave_prcnt_asn': ave_prcnt_asn[d]})
    entry.update({'ave_prcnt_othr': ave_prcnt_othr[d]})
    entry.update({'prcnt_stdnts_eligible_for_frl': prcnt_stdnts_eligible_for_frl[d]})
    
    #append the entry into the dist_data list
    dist_data.append(entry)
    

dist_data_dict = { 'district_data': dist_data}

pprint(dist_data_dict)
# Out:
# {'district_data': [{'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.5,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 98.0,
#                     'ave_school_enrol': 223.0,
#                     'district': 'Adams Township School District',
#                     'district_enrollment': 453,
#                     'fed_rev_per_s': 0.591611479,
#                     'lat': 47.05523415,
#                     'lng': -88.65829815,
#                     'loc_rev_per_s': 2.686534216,
#                     'prcnt_stdnts_eligible_for_frl': 53.5,
#                     'st_rev_per_s': 7.598233996,
#                     'tot_inst_per_s': 5.121412803999999,
#                     'tot_rev_per_s': 10.87637969,
#                     'tot_spend_per_s': 10.15452539},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 4.5,
#                     'ave_prcnt_wht': 88.0,
#                     'ave_school_enrol': 220.5,
#                     'district': 'Addison Community Schools',
#                     'district_enrollment': 855,
#                     'fed_rev_per_s': 1.321637427,
#                     'lat': 41.9882544,
#                     'lng': -84.34341309999998,
#                     'loc_rev_per_s': 5.8760233920000005,
#                     'prcnt_stdnts_eligible_for_frl': 51.5,
#                     'st_rev_per_s': 4.719298246,
#                     'tot_inst_per_s': 6.376608187,
#                     'tot_rev_per_s': 11.91695906,
#                     'tot_spend_per_s': 11.04561404},
#                    {'ave_prcnt_asn': 1.2,
#                     'ave_prcnt_bk': 4.0,
#                     'ave_prcnt_othr': 7.4,
#                     'ave_prcnt_wht': 58.2,
#                     'ave_school_enrol': 431.6,
#                     'district': 'Adrian, School District of the City of',
#                     'district_enrollment': 2963,
#                     'fed_rev_per_s': 2.159973,
#                     'lat': 41.89570634,
#                     'lng': -84.04982226,
#                     'loc_rev_per_s': 3.194060074,
#                     'prcnt_stdnts_eligible_for_frl': 70.4,
#                     'st_rev_per_s': 7.310833615,
#                     'tot_inst_per_s': 6.657104286,
#                     'tot_rev_per_s': 12.66486669,
#                     'tot_spend_per_s': 12.09922376},
#                    {'ave_prcnt_asn': 0.4,
#                     'ave_prcnt_bk': 3.2,
#                     'ave_prcnt_othr': 0.6,
#                     'ave_prcnt_wht': 91.8,
#                     'ave_school_enrol': 246.8,
#                     'district': 'Airport Community Schools',
#                     'district_enrollment': 2471,
#                     'fed_rev_per_s': 0.508700931,
#                     'lat': 42.04126472,
#                     'lng': -83.33854654,
#                     'loc_rev_per_s': 2.899635775,
#                     'prcnt_stdnts_eligible_for_frl': 56.2,
#                     'st_rev_per_s': 7.664103602000001,
#                     'tot_inst_per_s': 5.8543099960000005,
#                     'tot_rev_per_s': 11.07244031,
#                     'tot_spend_per_s': 10.78267908},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 0.5,
#                     'ave_prcnt_othr': 3.0,
#                     'ave_prcnt_wht': 88.5,
#                     'ave_school_enrol': 143.5,
#                     'district': 'Akron-Fairgrove Schools',
#                     'district_enrollment': 282,
#                     'fed_rev_per_s': 1.04964539,
#                     'lat': 43.5569764,
#                     'lng': -83.5299381,
#                     'loc_rev_per_s': 7.482269504,
#                     'prcnt_stdnts_eligible_for_frl': 74.0,
#                     'st_rev_per_s': 5.627659574,
#                     'tot_inst_per_s': 6.30141844,
#                     'tot_rev_per_s': 14.15957447,
#                     'tot_spend_per_s': 19.24468085},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 7.0,
#                     'ave_prcnt_wht': 90.0,
#                     'ave_school_enrol': 129.0,
#                     'district': 'Alba Public Schools',
#                     'district_enrollment': 136,
#                     'fed_rev_per_s': 1.088235294,
#                     'lat': 44.9777259,
#                     'lng': -84.97002409999997,
#                     'loc_rev_per_s': 6.272058824,
#                     'prcnt_stdnts_eligible_for_frl': 78.0,
#                     'st_rev_per_s': 5.426470588,
#                     'tot_inst_per_s': 6.183823529,
#                     'tot_rev_per_s': 12.78676471,
#                     'tot_spend_per_s': 11.58823529},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 1.5,
#                     'ave_prcnt_othr': 2.0,
#                     'ave_prcnt_wht': 94.0,
#                     'ave_school_enrol': 361.5,
#                     'district': 'Alcona Community Schools',
#                     'district_enrollment': 732,
#                     'fed_rev_per_s': 0.383879781,
#                     'lat': 44.65731165,
#                     'lng': -83.40420429999998,
#                     'loc_rev_per_s': 8.941256831,
#                     'prcnt_stdnts_eligible_for_frl': 69.5,
#                     'st_rev_per_s': 1.7404371580000002,
#                     'tot_inst_per_s': 6.329234972999999,
#                     'tot_rev_per_s': 11.06557377,
#                     'tot_spend_per_s': 10.15300546},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.666666667,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 97.33333333,
#                     'ave_school_enrol': 539.6666667000002,
#                     'district': 'Algonac Community School District',
#                     'district_enrollment': 1674,
#                     'fed_rev_per_s': 0.544802867,
#                     'lat': 42.63062513,
#                     'lng': -82.55720427,
#                     'loc_rev_per_s': 5.141577061,
#                     'prcnt_stdnts_eligible_for_frl': 47.66666667,
#                     'st_rev_per_s': 6.037037037,
#                     'tot_inst_per_s': 6.307048984,
#                     'tot_rev_per_s': 11.72341697,
#                     'tot_spend_per_s': 11.41397849},
#                    {'ave_prcnt_asn': 0.7142857140000001,
#                     'ave_prcnt_bk': 2.142857143,
#                     'ave_prcnt_othr': 4.428571429,
#                     'ave_prcnt_wht': 87.14285714,
#                     'ave_school_enrol': 363.2857143,
#                     'district': 'Allegan Public Schools',
#                     'district_enrollment': 2549,
#                     'fed_rev_per_s': 0.537073362,
#                     'lat': 42.52649179,
#                     'lng': -85.85679820000001,
#                     'loc_rev_per_s': 3.545704198,
#                     'prcnt_stdnts_eligible_for_frl': 61.14285714,
#                     'st_rev_per_s': 7.232640251,
#                     'tot_inst_per_s': 5.8265986660000015,
#                     'tot_rev_per_s': 11.31541781,
#                     'tot_spend_per_s': 10.509219300000002},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 2.333333333,
#                     'ave_prcnt_othr': 2.0,
#                     'ave_prcnt_wht': 83.0,
#                     'ave_school_enrol': 628.1666667000002,
#                     'district': 'Allen Park Public Schools',
#                     'district_enrollment': 3813,
#                     'fed_rev_per_s': 0.229478101,
#                     'lat': 42.24552257,
#                     'lng': -83.2133512,
#                     'loc_rev_per_s': 2.438237608,
#                     'prcnt_stdnts_eligible_for_frl': 41.66666667,
#                     'st_rev_per_s': 8.14135851,
#                     'tot_inst_per_s': 6.348019932000001,
#                     'tot_rev_per_s': 10.80907422,
#                     'tot_spend_per_s': 10.42617362},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 1.5,
#                     'ave_prcnt_othr': 3.75,
#                     'ave_prcnt_wht': 84.0,
#                     'ave_school_enrol': 637.5,
#                     'district': 'Allendale Public Schools',
#                     'district_enrollment': 2637,
#                     'fed_rev_per_s': 0.242320819,
#                     'lat': 42.96316008,
#                     'lng': -85.9611354,
#                     'loc_rev_per_s': 4.1111111110000005,
#                     'prcnt_stdnts_eligible_for_frl': 29.0,
#                     'st_rev_per_s': 7.446340537999999,
#                     'tot_inst_per_s': 5.93325749,
#                     'tot_rev_per_s': 11.79977247,
#                     'tot_spend_per_s': 10.97800531},
#                    {'ave_prcnt_asn': 1.5,
#                     'ave_prcnt_bk': 3.5,
#                     'ave_prcnt_othr': 1.5,
#                     'ave_prcnt_wht': 83.5,
#                     'ave_school_enrol': 412.25,
#                     'district': 'Alma Public Schools',
#                     'district_enrollment': 2134,
#                     'fed_rev_per_s': 0.7919400190000001,
#                     'lat': 43.38318695,
#                     'lng': -84.66388405,
#                     'loc_rev_per_s': 2.898313027,
#                     'prcnt_stdnts_eligible_for_frl': 60.5,
#                     'st_rev_per_s': 7.511246485,
#                     'tot_inst_per_s': 6.030927835,
#                     'tot_rev_per_s': 11.20149953,
#                     'tot_spend_per_s': 10.52061856},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 1.5,
#                     'ave_prcnt_wht': 93.0,
#                     'ave_school_enrol': 500.0,
#                     'district': 'Almont Community Schools',
#                     'district_enrollment': 1472,
#                     'fed_rev_per_s': 0.258152174,
#                     'lat': 42.93055800000001,
#                     'lng': -83.03980835,
#                     'loc_rev_per_s': 3.016304348,
#                     'prcnt_stdnts_eligible_for_frl': 26.5,
#                     'st_rev_per_s': 7.639266303999999,
#                     'tot_inst_per_s': 5.841032609,
#                     'tot_rev_per_s': 10.91372283,
#                     'tot_spend_per_s': 9.519021739},
#                    {'ave_prcnt_asn': 0.333333333,
#                     'ave_prcnt_bk': 0.666666667,
#                     'ave_prcnt_othr': 2.888888889,
#                     'ave_prcnt_wht': 94.66666667,
#                     'ave_school_enrol': 437.11111110000013,
#                     'district': 'Alpena Public Schools',
#                     'district_enrollment': 3937,
#                     'fed_rev_per_s': 0.891541783,
#                     'lat': 45.05164086,
#                     'lng': -83.47323887,
#                     'loc_rev_per_s': 3.074676149,
#                     'prcnt_stdnts_eligible_for_frl': 62.11111111,
#                     'st_rev_per_s': 6.613665227,
#                     'tot_inst_per_s': 5.5684531370000006,
#                     'tot_rev_per_s': 10.57988316,
#                     'tot_spend_per_s': 9.790449581},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 3.3636363639999995,
#                     'ave_prcnt_othr': 4.090909091,
#                     'ave_prcnt_wht': 89.18181818,
#                     'ave_school_enrol': 504.6363636,
#                     'district': 'Anchor Bay School District',
#                     'district_enrollment': 6111,
#                     'fed_rev_per_s': 0.194894453,
#                     'lat': 42.68233361,
#                     'lng': -82.75771275,
#                     'loc_rev_per_s': 3.031091474,
#                     'prcnt_stdnts_eligible_for_frl': 36.81818182,
#                     'st_rev_per_s': 7.682703322,
#                     'tot_inst_per_s': 5.905580101,
#                     'tot_rev_per_s': 10.90868925,
#                     'tot_spend_per_s': 10.16020291},
#                    {'ave_prcnt_asn': 11.96774194,
#                     'ave_prcnt_bk': 12.80645161,
#                     'ave_prcnt_othr': 9.903225806,
#                     'ave_prcnt_wht': 57.83870968,
#                     'ave_school_enrol': 520.6451613,
#                     'district': 'Ann Arbor Public Schools',
#                     'district_enrollment': 17233,
#                     'fed_rev_per_s': 0.352173156,
#                     'lat': 42.2740058,
#                     'lng': -83.73488591,
#                     'loc_rev_per_s': 8.094121742999999,
#                     'prcnt_stdnts_eligible_for_frl': 29.74193548,
#                     'st_rev_per_s': 6.0673707420000005,
#                     'tot_inst_per_s': 7.585156386,
#                     'tot_rev_per_s': 14.51366564,
#                     'tot_spend_per_s': 14.17524517},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 97.0,
#                     'ave_school_enrol': 564.5,
#                     'district': 'Armada Area Schools',
#                     'district_enrollment': 1891,
#                     'fed_rev_per_s': 0.129561079,
#                     'lat': 42.8480667,
#                     'lng': -82.8809153,
#                     'loc_rev_per_s': 4.041248017,
#                     'prcnt_stdnts_eligible_for_frl': 18.0,
#                     'st_rev_per_s': 6.653622422000001,
#                     'tot_inst_per_s': 5.465891063,
#                     'tot_rev_per_s': 10.82443152,
#                     'tot_spend_per_s': 10.18138551},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 96.0,
#                     'ave_school_enrol': 92.0,
#                     'district': 'Ashley Community Schools',
#                     'district_enrollment': 275,
#                     'fed_rev_per_s': 0.8,
#                     'lat': 43.1869573,
#                     'lng': -84.4726116,
#                     'loc_rev_per_s': 2.450909091,
#                     'prcnt_stdnts_eligible_for_frl': 55.0,
#                     'st_rev_per_s': 7.996363636,
#                     'tot_inst_per_s': 5.665454545,
#                     'tot_rev_per_s': 11.24727273,
#                     'tot_spend_per_s': 9.996363636},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 1.5,
#                     'ave_prcnt_othr': 7.5,
#                     'ave_prcnt_wht': 90.0,
#                     'ave_school_enrol': 283.0,
#                     'district': 'Athens Area Schools',
#                     'district_enrollment': 565,
#                     'fed_rev_per_s': 0.585840708,
#                     'lat': 42.1257686,
#                     'lng': -85.22105785,
#                     'loc_rev_per_s': 3.711504425,
#                     'prcnt_stdnts_eligible_for_frl': 44.0,
#                     'st_rev_per_s': 6.69380531,
#                     'tot_inst_per_s': 5.96460177,
#                     'tot_rev_per_s': 10.99115044,
#                     'tot_spend_per_s': 9.752212389},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 22.0,
#                     'ave_prcnt_othr': 8.0,
#                     'ave_prcnt_wht': 61.0,
#                     'ave_school_enrol': 300.3333333,
#                     'district': 'Atherton Community Schools',
#                     'district_enrollment': 922,
#                     'fed_rev_per_s': 0.863340564,
#                     'lat': 42.9835157,
#                     'lng': -83.62228,
#                     'loc_rev_per_s': 2.70824295,
#                     'prcnt_stdnts_eligible_for_frl': 79.33333333,
#                     'st_rev_per_s': 6.526030369,
#                     'tot_inst_per_s': 5.053145336,
#                     'tot_rev_per_s': 10.09761388,
#                     'tot_spend_per_s': 9.30802603},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 4.0,
#                     'ave_prcnt_wht': 92.0,
#                     'ave_school_enrol': 259.0,
#                     'district': 'Atlanta Community Schools',
#                     'district_enrollment': 258,
#                     'fed_rev_per_s': 1.298449612,
#                     'lat': 44.9939631,
#                     'lng': -84.1492465,
#                     'loc_rev_per_s': 9.84496124,
#                     'prcnt_stdnts_eligible_for_frl': 72.0,
#                     'st_rev_per_s': 1.310077519,
#                     'tot_inst_per_s': 6.647286822000001,
#                     'tot_rev_per_s': 12.45348837,
#                     'tot_spend_per_s': 11.12790698},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 3.0,
#                     'ave_prcnt_wht': 93.5,
#                     'ave_school_enrol': 156.5,
#                     'district': 'Au Gres-Sims School District',
#                     'district_enrollment': 386,
#                     'fed_rev_per_s': 0.974093264,
#                     'lat': 44.04620720000001,
#                     'lng': -83.6969632,
#                     'loc_rev_per_s': 6.520725389,
#                     'prcnt_stdnts_eligible_for_frl': 60.0,
#                     'st_rev_per_s': 3.932642487,
#                     'tot_inst_per_s': 6.044041451,
#                     'tot_rev_per_s': 11.42746114,
#                     'tot_spend_per_s': 9.968911917},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 10.0,
#                     'ave_prcnt_wht': 87.0,
#                     'ave_school_enrol': 31.0,
#                     'district': 'AuTrain-Onota Public Schools',
#                     'district_enrollment': 31,
#                     'fed_rev_per_s': 2.129032258,
#                     'lat': 46.4744396,
#                     'lng': -87.0424802,
#                     'loc_rev_per_s': 27.12903226,
#                     'prcnt_stdnts_eligible_for_frl': 74.0,
#                     'st_rev_per_s': 3.225806452,
#                     'tot_inst_per_s': 16.25806452,
#                     'tot_rev_per_s': 32.48387097,
#                     'tot_spend_per_s': 31.67741935},
#                    {'ave_prcnt_asn': 11.5,
#                     'ave_prcnt_bk': 18.33333333,
#                     'ave_prcnt_othr': 5.166666667,
#                     'ave_prcnt_wht': 59.66666667,
#                     'ave_school_enrol': 534.5,
#                     'district': 'Avondale School District',
#                     'district_enrollment': 3326,
#                     'fed_rev_per_s': 0.457907396,
#                     'lat': 42.62679418,
#                     'lng': -83.19055388,
#                     'loc_rev_per_s': 6.077269994,
#                     'prcnt_stdnts_eligible_for_frl': 46.5,
#                     'st_rev_per_s': 7.983764281,
#                     'tot_inst_per_s': 7.172579675,
#                     'tot_rev_per_s': 14.51894167,
#                     'tot_spend_per_s': 13.56794949},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 0.75,
#                     'ave_prcnt_othr': 1.5,
#                     'ave_prcnt_wht': 94.75,
#                     'ave_school_enrol': 251.0,
#                     'district': 'Bad Axe Public Schools',
#                     'district_enrollment': 1013,
#                     'fed_rev_per_s': 0.585389931,
#                     'lat': 43.80520388,
#                     'lng': -83.0143088,
#                     'loc_rev_per_s': 3.5972359330000003,
#                     'prcnt_stdnts_eligible_for_frl': 56.25,
#                     'st_rev_per_s': 6.898321816,
#                     'tot_inst_per_s': 6.2744323789999985,
#                     'tot_rev_per_s': 11.08094768,
#                     'tot_spend_per_s': 10.15301086},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 40.0,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 56.0,
#                     'ave_school_enrol': 128.0,
#                     'district': 'Baldwin Community Schools',
#                     'district_enrollment': 557,
#                     'fed_rev_per_s': 2.299820467,
#                     'lat': 43.8895519,
#                     'lng': -85.85583609999998,
#                     'loc_rev_per_s': 12.1005386,
#                     'prcnt_stdnts_eligible_for_frl': 91.0,
#                     'st_rev_per_s': 21.28904847,
#                     'tot_inst_per_s': 8.754039497,
#                     'tot_rev_per_s': 35.68940754,
#                     'tot_spend_per_s': 34.8438061},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 5.0,
#                     'ave_prcnt_othr': 7.0,
#                     'ave_prcnt_wht': 61.66666667,
#                     'ave_school_enrol': 287.0,
#                     'district': 'Bangor Public Schools (Van Buren)',
#                     'district_enrollment': 1239,
#                     'fed_rev_per_s': 1.401937046,
#                     'lat': 42.3069768,
#                     'lng': -86.11874897,
#                     'loc_rev_per_s': 1.970137207,
#                     'prcnt_stdnts_eligible_for_frl': 75.33333333,
#                     'st_rev_per_s': 7.488297014,
#                     'tot_inst_per_s': 5.7812752220000005,
#                     'tot_rev_per_s': 10.86037127,
#                     'tot_spend_per_s': 10.32445521},
#                    {'ave_prcnt_asn': 0.833333333,
#                     'ave_prcnt_bk': 8.333333332999999,
#                     'ave_prcnt_othr': 2.5,
#                     'ave_prcnt_wht': 83.5,
#                     'ave_school_enrol': 557.0,
#                     'district': 'Bangor Township Schools',
#                     'district_enrollment': 2511,
#                     'fed_rev_per_s': 0.446435683,
#                     'lat': 43.6273284,
#                     'lng': -83.9170745,
#                     'loc_rev_per_s': 1.754281163,
#                     'prcnt_stdnts_eligible_for_frl': 60.16666667,
#                     'st_rev_per_s': 7.484667462999999,
#                     'tot_inst_per_s': 5.457188371,
#                     'tot_rev_per_s': 9.685384309,
#                     'tot_spend_per_s': 9.246117085},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 44.0,
#                     'ave_prcnt_wht': 56.0,
#                     'ave_school_enrol': 424.0,
#                     'district': 'Baraga Area Schools',
#                     'district_enrollment': 430,
#                     'fed_rev_per_s': 2.448837209,
#                     'lat': 46.7778547,
#                     'lng': -88.5869031,
#                     'loc_rev_per_s': 4.4046511630000005,
#                     'prcnt_stdnts_eligible_for_frl': 64.0,
#                     'st_rev_per_s': 7.313953487999999,
#                     'tot_inst_per_s': 7.181395349,
#                     'tot_rev_per_s': 14.16744186,
#                     'tot_spend_per_s': 11.85813953},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 12.0,
#                     'ave_prcnt_wht': 87.0,
#                     'ave_school_enrol': 316.0,
#                     'district': 'Bark River-Harris School District',
#                     'district_enrollment': 738,
#                     'fed_rev_per_s': 0.764227642,
#                     'lat': 45.7023805,
#                     'lng': -87.3448971,
#                     'loc_rev_per_s': 1.10704607,
#                     'prcnt_stdnts_eligible_for_frl': 47.0,
#                     'st_rev_per_s': 7.850948509,
#                     'tot_inst_per_s': 5.906504065,
#                     'tot_rev_per_s': 9.722222222000001,
#                     'tot_spend_per_s': 10.16666667},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 1.666666667,
#                     'ave_prcnt_othr': 6.0,
#                     'ave_prcnt_wht': 85.0,
#                     'ave_school_enrol': 367.3333333,
#                     'district': 'Bath Community Schools',
#                     'district_enrollment': 1124,
#                     'fed_rev_per_s': 0.326512456,
#                     'lat': 42.81629137,
#                     'lng': -84.4446631,
#                     'loc_rev_per_s': 3.838967972,
#                     'prcnt_stdnts_eligible_for_frl': 43.33333333,
#                     'st_rev_per_s': 7.193060498,
#                     'tot_inst_per_s': 5.596975089,
#                     'tot_rev_per_s': 11.35854093,
#                     'tot_spend_per_s': 9.90658363},
#                    {'ave_prcnt_asn': 1.777777778,
#                     'ave_prcnt_bk': 32.44444444,
#                     'ave_prcnt_othr': 10.66666667,
#                     'ave_prcnt_wht': 42.44444444,
#                     'ave_school_enrol': 436.11111110000013,
#                     'district': 'Battle Creek Public Schools',
#                     'district_enrollment': 4474,
#                     'fed_rev_per_s': 2.223066607,
#                     'lat': 42.32954503,
#                     'lng': -85.20535829,
#                     'loc_rev_per_s': 4.232007152,
#                     'prcnt_stdnts_eligible_for_frl': 88.33333333,
#                     'st_rev_per_s': 8.04738489,
#                     'tot_inst_per_s': 7.351586947,
#                     'tot_rev_per_s': 14.50245865,
#                     'tot_spend_per_s': 14.16919982},
#                    {'ave_prcnt_asn': 3.333333333,
#                     'ave_prcnt_bk': 3.833333333,
#                     'ave_prcnt_othr': 5.833333333,
#                     'ave_prcnt_wht': 77.25,
#                     'ave_school_enrol': 525.8333333,
#                     'district': 'Bay City School District',
#                     'district_enrollment': 7941,
#                     'fed_rev_per_s': 0.750787055,
#                     'lat': 43.59591014,
#                     'lng': -83.92485015,
#                     'loc_rev_per_s': 2.087772321,
#                     'prcnt_stdnts_eligible_for_frl': 62.33333333,
#                     'st_rev_per_s': 7.658103512999999,
#                     'tot_inst_per_s': 5.8375519460000005,
#                     'tot_rev_per_s': 10.49666289,
#                     'tot_spend_per_s': 9.926457625},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 5.5,
#                     'ave_prcnt_wht': 90.5,
#                     'ave_school_enrol': 343.0,
#                     'district': 'Beal City Public Schools',
#                     'district_enrollment': 690,
#                     'fed_rev_per_s': 0.276811594,
#                     'lat': 43.67023325,
#                     'lng': -84.91086125,
#                     'loc_rev_per_s': 2.285507246,
#                     'prcnt_stdnts_eligible_for_frl': 33.5,
#                     'st_rev_per_s': 7.997101449,
#                     'tot_inst_per_s': 6.015942029,
#                     'tot_rev_per_s': 10.55942029,
#                     'tot_spend_per_s': 9.895652174},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 89.0,
#                     'ave_school_enrol': 148.0,
#                     'district': 'Bear Lake Schools',
#                     'district_enrollment': 302,
#                     'fed_rev_per_s': 0.675496689,
#                     'lat': 44.4192692,
#                     'lng': -86.1467774,
#                     'loc_rev_per_s': 5.324503311,
#                     'prcnt_stdnts_eligible_for_frl': 51.0,
#                     'st_rev_per_s': 5.400662252,
#                     'tot_inst_per_s': 5.453642384,
#                     'tot_rev_per_s': 11.40066225,
#                     'tot_spend_per_s': 10.13245033},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 2.0,
#                     'ave_prcnt_wht': 98.0,
#                     'ave_school_enrol': 50.0,
#                     'district': 'Beaver Island Community School',
#                     'district_enrollment': 51,
#                     'fed_rev_per_s': 1.274509804,
#                     'lat': 45.74568,
#                     'lng': -85.5227065,
#                     'loc_rev_per_s': 34.90196078,
#                     'prcnt_stdnts_eligible_for_frl': 39.0,
#                     'st_rev_per_s': 5.647058824,
#                     'tot_inst_per_s': 27.03921569,
#                     'tot_rev_per_s': 41.82352941,
#                     'tot_spend_per_s': 43.11764706},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 0.5,
#                     'ave_prcnt_othr': 2.0,
#                     'ave_prcnt_wht': 94.5,
#                     'ave_school_enrol': 573.5,
#                     'district': 'Beaverton Rural Schools',
#                     'district_enrollment': 1157,
#                     'fed_rev_per_s': 0.862575627,
#                     'lat': 43.8753045,
#                     'lng': -84.4879882,
#                     'loc_rev_per_s': 2.95505618,
#                     'prcnt_stdnts_eligible_for_frl': 59.5,
#                     'st_rev_per_s': 6.326707001,
#                     'tot_inst_per_s': 5.894554883,
#                     'tot_rev_per_s': 10.14433881,
#                     'tot_spend_per_s': 12.21521175},
#                    {'ave_prcnt_asn': 1.333333333,
#                     'ave_prcnt_bk': 0.333333333,
#                     'ave_prcnt_othr': 1.666666667,
#                     'ave_prcnt_wht': 91.0,
#                     'ave_school_enrol': 775.0,
#                     'district': 'Bedford Public Schools',
#                     'district_enrollment': 4460,
#                     'fed_rev_per_s': 0.224439462,
#                     'lat': 41.76266957,
#                     'lng': -83.60413977,
#                     'loc_rev_per_s': 1.867040359,
#                     'prcnt_stdnts_eligible_for_frl': 25.66666667,
#                     'st_rev_per_s': 7.670179372000001,
#                     'tot_inst_per_s': 6.0107623320000005,
#                     'tot_rev_per_s': 9.761659193,
#                     'tot_spend_per_s': 10.21210762},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 88.0,
#                     'ave_prcnt_othr': 3.5,
#                     'ave_prcnt_wht': 5.5,
#                     'ave_school_enrol': 348.0,
#                     'district': 'Beecher Community School District',
#                     'district_enrollment': 977,
#                     'fed_rev_per_s': 3.779938588,
#                     'lat': 43.09244495,
#                     'lng': -83.70048259999999,
#                     'loc_rev_per_s': 1.354145343,
#                     'prcnt_stdnts_eligible_for_frl': 87.5,
#                     'st_rev_per_s': 8.587512794,
#                     'tot_inst_per_s': 6.306038895,
#                     'tot_rev_per_s': 13.72159672,
#                     'tot_spend_per_s': 13.96212897},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 3.0,
#                     'ave_prcnt_wht': 87.75,
#                     'ave_school_enrol': 457.75,
#                     'district': 'Belding Area School District',
#                     'district_enrollment': 1901,
#                     'fed_rev_per_s': 0.823776959,
#                     'lat': 43.09598398,
#                     'lng': -85.23121315,
#                     'loc_rev_per_s': 3.455549711,
#                     'prcnt_stdnts_eligible_for_frl': 62.5,
#                     'st_rev_per_s': 7.728563913999999,
#                     'tot_inst_per_s': 6.052077854,
#                     'tot_rev_per_s': 12.00789058,
#                     'tot_spend_per_s': 11.94476591},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 0.5,
#                     'ave_prcnt_othr': 6.5,
#                     'ave_prcnt_wht': 90.5,
#                     'ave_school_enrol': 192.0,
#                     'district': 'Bellaire Public Schools',
#                     'district_enrollment': 381,
#                     'fed_rev_per_s': 0.559055118,
#                     'lat': 44.982142,
#                     'lng': -85.21775265,
#                     'loc_rev_per_s': 12.44619423,
#                     'prcnt_stdnts_eligible_for_frl': 45.5,
#                     'st_rev_per_s': 0.88976378,
#                     'tot_inst_per_s': 6.375328084,
#                     'tot_rev_per_s': 13.89501312,
#                     'tot_spend_per_s': 11.78215223},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 3.0,
#                     'ave_prcnt_othr': 2.0,
#                     'ave_prcnt_wht': 93.5,
#                     'ave_school_enrol': 290.0,
#                     'district': 'Bellevue Community Schools',
#                     'district_enrollment': 569,
#                     'fed_rev_per_s': 0.676625659,
#                     'lat': 42.4483325,
#                     'lng': -85.02740425,
#                     'loc_rev_per_s': 3.92970123,
#                     'prcnt_stdnts_eligible_for_frl': 60.5,
#                     'st_rev_per_s': 7.722319859,
#                     'tot_inst_per_s': 6.012302285,
#                     'tot_rev_per_s': 12.32864675,
#                     'tot_spend_per_s': 11.87170475},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 7.5,
#                     'ave_prcnt_othr': 8.25,
#                     'ave_prcnt_wht': 77.75,
#                     'ave_school_enrol': 296.5,
#                     'district': 'Bendle Public Schools',
#                     'district_enrollment': 1190,
#                     'fed_rev_per_s': 1.026890756,
#                     'lat': 42.9706472,
#                     'lng': -83.665604,
#                     'loc_rev_per_s': 1.863865546,
#                     'prcnt_stdnts_eligible_for_frl': 92.75,
#                     'st_rev_per_s': 8.073109244,
#                     'tot_inst_per_s': 5.5731092439999985,
#                     'tot_rev_per_s': 10.96386555,
#                     'tot_spend_per_s': 10.38151261},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 8.0,
#                     'ave_prcnt_othr': 5.5,
#                     'ave_prcnt_wht': 80.5,
#                     'ave_school_enrol': 311.0,
#                     'district': 'Bentley Community School District',
#                     'district_enrollment': 872,
#                     'fed_rev_per_s': 0.686926606,
#                     'lat': 43.0221933,
#                     'lng': -83.5949787,
#                     'loc_rev_per_s': 2.107798165,
#                     'prcnt_stdnts_eligible_for_frl': 74.0,
#                     'st_rev_per_s': 7.461009174,
#                     'tot_inst_per_s': 5.271788991,
#                     'tot_rev_per_s': 10.25573394,
#                     'tot_spend_per_s': 14.57798165},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 90.0,
#                     'ave_prcnt_othr': 2.25,
#                     'ave_prcnt_wht': 2.5,
#                     'ave_school_enrol': 426.0,
#                     'district': 'Benton Harbor Area Schools',
#                     'district_enrollment': 2200,
#                     'fed_rev_per_s': 2.945454545,
#                     'lat': 42.10499965,
#                     'lng': -86.44224675,
#                     'loc_rev_per_s': 4.174545455,
#                     'prcnt_stdnts_eligible_for_frl': 82.0,
#                     'st_rev_per_s': 6.3363636360000015,
#                     'tot_inst_per_s': 5.534545455,
#                     'tot_rev_per_s': 13.45636364,
#                     'tot_spend_per_s': 13.19727273},
#                    {'ave_prcnt_asn': 0.6,
#                     'ave_prcnt_bk': 0.4,
#                     'ave_prcnt_othr': 5.0,
#                     'ave_prcnt_wht': 90.8,
#                     'ave_school_enrol': 236.4,
#                     'district': 'Benzie County Central Schools',
#                     'district_enrollment': 1505,
#                     'fed_rev_per_s': 0.593355482,
#                     'lat': 44.60614142,
#                     'lng': -85.99862270000001,
#                     'loc_rev_per_s': 5.982724252000001,
#                     'prcnt_stdnts_eligible_for_frl': 60.6,
#                     'st_rev_per_s': 4.284385382,
#                     'tot_inst_per_s': 5.968106312000001,
#                     'tot_rev_per_s': 10.86046512,
#                     'tot_spend_per_s': 9.998006645},
#                    {'ave_prcnt_asn': 1.285714286,
#                     'ave_prcnt_bk': 16.85714286,
#                     'ave_prcnt_othr': 3.0,
#                     'ave_prcnt_wht': 64.42857143,
#                     'ave_school_enrol': 618.8571429,
#                     'district': 'Berkley School District',
#                     'district_enrollment': 4404,
#                     'fed_rev_per_s': 0.257947321,
#                     'lat': 42.49434944,
#                     'lng': -83.18678114,
#                     'loc_rev_per_s': 3.835831063,
#                     'prcnt_stdnts_eligible_for_frl': 31.71428571,
#                     'st_rev_per_s': 10.31289737,
#                     'tot_inst_per_s': 8.123524069,
#                     'tot_rev_per_s': 14.40667575,
#                     'tot_spend_per_s': 16.56039964},
#                    {'ave_prcnt_asn': 2.888888889,
#                     'ave_prcnt_bk': 16.22222222,
#                     'ave_prcnt_othr': 8.111111111,
#                     'ave_prcnt_wht': 58.33333333,
#                     'ave_school_enrol': 245.4444444,
#                     'district': 'Berrien Springs Public Schools',
#                     'district_enrollment': 3209,
#                     'fed_rev_per_s': 0.508258024,
#                     'lat': 42.41158543,
#                     'lng': -85.89934248,
#                     'loc_rev_per_s': 1.43346837,
#                     'prcnt_stdnts_eligible_for_frl': 63.55555556,
#                     'st_rev_per_s': 8.929261452,
#                     'tot_inst_per_s': 4.67341851,
#                     'tot_rev_per_s': 10.87098785,
#                     'tot_spend_per_s': 9.600498598},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 1.5,
#                     'ave_prcnt_othr': 3.0,
#                     'ave_prcnt_wht': 93.0,
#                     'ave_school_enrol': 196.0,
#                     'district': 'Bessemer Area School District',
#                     'district_enrollment': 395,
#                     'fed_rev_per_s': 0.7164556959999999,
#                     'lat': 46.4316204,
#                     'lng': -89.99729845,
#                     'loc_rev_per_s': 2.270886076,
#                     'prcnt_stdnts_eligible_for_frl': 56.5,
#                     'st_rev_per_s': 7.617721519,
#                     'tot_inst_per_s': 6.103797468,
#                     'tot_rev_per_s': 10.60506329,
#                     'tot_spend_per_s': 9.84556962},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 22.0,
#                     'ave_prcnt_wht': 76.0,
#                     'ave_school_enrol': 209.0,
#                     'district': 'Big Bay De Noc School District',
#                     'district_enrollment': 208,
#                     'fed_rev_per_s': 1.7980769230000002,
#                     'lat': 45.8688554,
#                     'lng': -86.5245927,
#                     'loc_rev_per_s': 9.365384615,
#                     'prcnt_stdnts_eligible_for_frl': 66.0,
#                     'st_rev_per_s': 1.836538462,
#                     'tot_inst_per_s': 6.25,
#                     'tot_rev_per_s': 13.0,
#                     'tot_spend_per_s': 12.63942308},
#                    {'ave_prcnt_asn': 1.4,
#                     'ave_prcnt_bk': 6.0,
#                     'ave_prcnt_othr': 3.4,
#                     'ave_prcnt_wht': 87.6,
#                     'ave_school_enrol': 386.2,
#                     'district': 'Big Rapids Public Schools',
#                     'district_enrollment': 1946,
#                     'fed_rev_per_s': 0.704008222,
#                     'lat': 43.69173538,
#                     'lng': -85.49306428,
#                     'loc_rev_per_s': 3.232271326,
#                     'prcnt_stdnts_eligible_for_frl': 54.4,
#                     'st_rev_per_s': 6.689105858,
#                     'tot_inst_per_s': 5.700411099999998,
#                     'tot_rev_per_s': 10.62538541,
#                     'tot_spend_per_s': 9.648509764},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 1.666666667,
#                     'ave_prcnt_othr': 3.333333333,
#                     'ave_prcnt_wht': 87.0,
#                     'ave_school_enrol': 501.33333330000005,
#                     'district': 'Birch Run Area Schools',
#                     'district_enrollment': 1891,
#                     'fed_rev_per_s': 0.5737704920000001,
#                     'lat': 43.24719753,
#                     'lng': -83.79414809999999,
#                     'loc_rev_per_s': 1.767318879,
#                     'prcnt_stdnts_eligible_for_frl': 51.0,
#                     'st_rev_per_s': 7.405076678999999,
#                     'tot_inst_per_s': 5.485986251,
#                     'tot_rev_per_s': 9.74616605,
#                     'tot_spend_per_s': 9.034902168},
#                    {'ave_prcnt_asn': 3.461538462,
#                     'ave_prcnt_bk': 12.92307692,
#                     'ave_prcnt_othr': 3.384615385,
#                     'ave_prcnt_wht': 77.38461538,
#                     'ave_school_enrol': 609.7692308,
#                     'district': 'Birmingham Public Schools',
#                     'district_enrollment': 8132,
#                     'fed_rev_per_s': 0.091121495,
#                     'lat': 42.53931824,
#                     'lng': -83.23717242,
#                     'loc_rev_per_s': 10.03344811,
#                     'prcnt_stdnts_eligible_for_frl': 8.461538462,
#                     'st_rev_per_s': 7.477619282,
#                     'tot_inst_per_s': 9.294269552000001,
#                     'tot_rev_per_s': 17.60218888,
#                     'tot_spend_per_s': 16.6122725},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 2.0,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 90.5,
#                     'ave_school_enrol': 332.5,
#                     'district': 'Blissfield Community Schools',
#                     'district_enrollment': 1186,
#                     'fed_rev_per_s': 0.409780776,
#                     'lat': 41.82217825,
#                     'lng': -83.8688091,
#                     'loc_rev_per_s': 1.99915683,
#                     'prcnt_stdnts_eligible_for_frl': 31.5,
#                     'st_rev_per_s': 7.438448567000001,
#                     'tot_inst_per_s': 6.032040472,
#                     'tot_rev_per_s': 9.847386172,
#                     'tot_spend_per_s': 9.514333895},
#                    {'ave_prcnt_asn': 9.222222222000001,
#                     'ave_prcnt_bk': 11.33333333,
#                     'ave_prcnt_othr': 5.222222222,
#                     'ave_prcnt_wht': 71.66666667,
#                     'ave_school_enrol': 577.0,
#                     'district': 'Bloomfield Hills Schools',
#                     'district_enrollment': 5473,
#                     'fed_rev_per_s': 0.124063585,
#                     'lat': 42.57354477,
#                     'lng': -83.28611131,
#                     'loc_rev_per_s': 11.394482,
#                     'prcnt_stdnts_eligible_for_frl': 14.33333333,
#                     'st_rev_per_s': 8.086789695,
#                     'tot_inst_per_s': 10.79590718,
#                     'tot_rev_per_s': 19.60533528,
#                     'tot_spend_per_s': 22.84615385},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 4.666666667,
#                     'ave_prcnt_othr': 2.666666667,
#                     'ave_prcnt_wht': 57.0,
#                     'ave_school_enrol': 375.0,
#                     'district': 'Bloomingdale Public School District',
#                     'district_enrollment': 1221,
#                     'fed_rev_per_s': 0.924651925,
#                     'lat': 42.41766013,
#                     'lng': -85.99782303,
#                     'loc_rev_per_s': 2.397215397,
#                     'prcnt_stdnts_eligible_for_frl': 85.66666667,
#                     'st_rev_per_s': 7.4185094189999985,
#                     'tot_inst_per_s': 5.974610975,
#                     'tot_rev_per_s': 10.74037674,
#                     'tot_spend_per_s': 9.907452907},
#                    {'ave_prcnt_asn': 0.75,
#                     'ave_prcnt_bk': 0.25,
#                     'ave_prcnt_othr': 6.25,
#                     'ave_prcnt_wht': 90.25,
#                     'ave_school_enrol': 333.25,
#                     'district': 'Boyne City Public Schools',
#                     'district_enrollment': 1315,
#                     'fed_rev_per_s': 0.415209125,
#                     'lat': 45.20819960000001,
#                     'lng': -85.00214940000002,
#                     'loc_rev_per_s': 6.692775665,
#                     'prcnt_stdnts_eligible_for_frl': 53.5,
#                     'st_rev_per_s': 4.137642586,
#                     'tot_inst_per_s': 6.509505702999999,
#                     'tot_rev_per_s': 11.24562738,
#                     'tot_spend_per_s': 9.862357414},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 14.0,
#                     'ave_prcnt_wht': 85.0,
#                     'ave_school_enrol': 150.0,
#                     'district': 'Boyne Falls Public School District',
#                     'district_enrollment': 151,
#                     'fed_rev_per_s': 0.834437086,
#                     'lat': 45.181619,
#                     'lng': -84.93941219999998,
#                     'loc_rev_per_s': 18.35761589,
#                     'prcnt_stdnts_eligible_for_frl': 70.0,
#                     'st_rev_per_s': 1.496688742,
#                     'tot_inst_per_s': 11.17218543,
#                     'tot_rev_per_s': 20.68874172,
#                     'tot_spend_per_s': 19.84768212},
#                    {'ave_prcnt_asn': 1.5,
#                     'ave_prcnt_bk': 3.75,
#                     'ave_prcnt_othr': 2.25,
#                     'ave_prcnt_wht': 87.0,
#                     'ave_school_enrol': 559.5,
#                     'district': 'Brandon School District in the Counties of '
#                                 'Oakland and Lapeer',
#                     'district_enrollment': 2727,
#                     'fed_rev_per_s': 0.318298497,
#                     'lat': 42.84904798,
#                     'lng': -83.43218445,
#                     'loc_rev_per_s': 4.4363769710000005,
#                     'prcnt_stdnts_eligible_for_frl': 36.25,
#                     'st_rev_per_s': 7.672900622999999,
#                     'tot_inst_per_s': 5.514118077999999,
#                     'tot_rev_per_s': 12.42757609,
#                     'tot_spend_per_s': 11.05390539},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 3.5,
#                     'ave_prcnt_othr': 4.5,
#                     'ave_prcnt_wht': 85.0,
#                     'ave_school_enrol': 312.0,
#                     'district': 'Brandywine Community Schools',
#                     'district_enrollment': 1359,
#                     'fed_rev_per_s': 0.551140545,
#                     'lat': 41.7904532,
#                     'lng': -86.23979820000002,
#                     'loc_rev_per_s': 2.679175865,
#                     'prcnt_stdnts_eligible_for_frl': 65.5,
#                     'st_rev_per_s': 7.394407652999999,
#                     'tot_inst_per_s': 5.705665931,
#                     'tot_rev_per_s': 10.62472406,
#                     'tot_spend_per_s': 10.29065489},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 1.5,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 89.5,
#                     'ave_school_enrol': 344.0,
#                     'district': 'Breckenridge Community Schools',
#                     'district_enrollment': 717,
#                     'fed_rev_per_s': 0.59693166,
#                     'lat': 43.41316970000001,
#                     'lng': -84.47393765,
#                     'loc_rev_per_s': 2.9972106,
#                     'prcnt_stdnts_eligible_for_frl': 51.5,
#                     'st_rev_per_s': 7.365411437000001,
#                     'tot_inst_per_s': 6.207810321,
#                     'tot_rev_per_s': 10.9595537,
# ...
#                     'tot_inst_per_s': 5.548738247999999,
#                     'tot_rev_per_s': 11.51657595,
#                     'tot_spend_per_s': 10.521524},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 3.333333333,
#                     'ave_prcnt_wht': 94.33333333,
#                     'ave_school_enrol': 280.3333333,
#                     'district': 'West Iron County Public Schools',
#                     'district_enrollment': 850,
#                     'fed_rev_per_s': 0.938823529,
#                     'lat': 46.0819967,
#                     'lng': -88.633486,
#                     'loc_rev_per_s': 3.722352941,
#                     'prcnt_stdnts_eligible_for_frl': 68.0,
#                     'st_rev_per_s': 5.412941176,
#                     'tot_inst_per_s': 6.304705882,
#                     'tot_rev_per_s': 10.07411765,
#                     'tot_spend_per_s': 10.24823529},
#                    {'ave_prcnt_asn': 6.909090909,
#                     'ave_prcnt_bk': 3.0,
#                     'ave_prcnt_othr': 5.818181817999999,
#                     'ave_prcnt_wht': 47.0,
#                     'ave_school_enrol': 618.8181818,
#                     'district': 'West Ottawa Public School District',
#                     'district_enrollment': 6925,
#                     'fed_rev_per_s': 0.8001444040000001,
#                     'lat': 42.83554316,
#                     'lng': -86.13929955,
#                     'loc_rev_per_s': 5.024404332,
#                     'prcnt_stdnts_eligible_for_frl': 59.54545455,
#                     'st_rev_per_s': 7.132418773,
#                     'tot_inst_per_s': 7.168953069,
#                     'tot_rev_per_s': 12.95696751,
#                     'tot_spend_per_s': 13.08592058},
#                    {'ave_prcnt_asn': 0.833333333,
#                     'ave_prcnt_bk': 2.5,
#                     'ave_prcnt_othr': 5.0,
#                     'ave_prcnt_wht': 88.33333333,
#                     'ave_school_enrol': 485.83333330000005,
#                     'district': 'Western School District',
#                     'district_enrollment': 2946,
#                     'fed_rev_per_s': 0.296334012,
#                     'lat': 42.28354027,
#                     'lng': -84.36658685,
#                     'loc_rev_per_s': 2.470807875,
#                     'prcnt_stdnts_eligible_for_frl': 42.66666667,
#                     'st_rev_per_s': 7.705702648,
#                     'tot_inst_per_s': 6.490156144,
#                     'tot_rev_per_s': 10.47284453,
#                     'tot_spend_per_s': 10.0023761},
#                    {'ave_prcnt_asn': 0.6,
#                     'ave_prcnt_bk': 80.6,
#                     'ave_prcnt_othr': 1.2,
#                     'ave_prcnt_wht': 15.0,
#                     'ave_school_enrol': 333.0,
#                     'district': 'Westwood Community School District',
#                     'district_enrollment': 2076,
#                     'fed_rev_per_s': 1.699903661,
#                     'lat': 42.28394852,
#                     'lng': -83.2884595,
#                     'loc_rev_per_s': 1.70327553,
#                     'prcnt_stdnts_eligible_for_frl': 85.6,
#                     'st_rev_per_s': 8.262042389,
#                     'tot_inst_per_s': 6.2808285160000015,
#                     'tot_rev_per_s': 11.66522158,
#                     'tot_spend_per_s': 11.4238921},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 84.0,
#                     'ave_prcnt_othr': 4.0,
#                     'ave_prcnt_wht': 9.75,
#                     'ave_school_enrol': 319.25,
#                     'district': 'Westwood Heights Schools',
#                     'district_enrollment': 1357,
#                     'fed_rev_per_s': 1.04642594,
#                     'lat': 43.06376548,
#                     'lng': -83.74683403,
#                     'loc_rev_per_s': 1.535740604,
#                     'prcnt_stdnts_eligible_for_frl': 87.75,
#                     'st_rev_per_s': 7.72807664,
#                     'tot_inst_per_s': 5.064112012,
#                     'tot_rev_per_s': 10.31024318,
#                     'tot_spend_per_s': 10.21518055},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 3.0,
#                     'ave_prcnt_othr': 3.0,
#                     'ave_prcnt_wht': 90.0,
#                     'ave_school_enrol': 288.0,
#                     'district': 'White Cloud Public Schools',
#                     'district_enrollment': 990,
#                     'fed_rev_per_s': 0.953535354,
#                     'lat': 43.5509485,
#                     'lng': -85.7867046,
#                     'loc_rev_per_s': 3.297979798,
#                     'prcnt_stdnts_eligible_for_frl': 66.0,
#                     'st_rev_per_s': 6.9838383839999985,
#                     'tot_inst_per_s': 6.015151515,
#                     'tot_rev_per_s': 11.23535354,
#                     'tot_spend_per_s': 10.12626263},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 0.0,
#                     'ave_prcnt_othr': 4.0,
#                     'ave_prcnt_wht': 86.5,
#                     'ave_school_enrol': 381.5,
#                     'district': 'White Pigeon Community Schools',
#                     'district_enrollment': 750,
#                     'fed_rev_per_s': 0.8533333329999999,
#                     'lat': 41.79983635,
#                     'lng': -85.63738025,
#                     'loc_rev_per_s': 5.921333333,
#                     'prcnt_stdnts_eligible_for_frl': 60.5,
#                     'st_rev_per_s': 4.86,
#                     'tot_inst_per_s': 6.692,
#                     'tot_rev_per_s': 11.63466667,
#                     'tot_spend_per_s': 11.70666667},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 4.0,
#                     'ave_prcnt_othr': 4.0,
#                     'ave_prcnt_wht': 92.0,
#                     'ave_school_enrol': 26.0,
#                     'district': 'Whitefish Township Schools',
#                     'district_enrollment': 17,
#                     'fed_rev_per_s': 4.294117647,
#                     'lat': 46.6104739,
#                     'lng': -85.0391144,
#                     'loc_rev_per_s': 60.94117647,
#                     'prcnt_stdnts_eligible_for_frl': 64.0,
#                     'st_rev_per_s': 18.58823529,
#                     'tot_inst_per_s': 22.35294118,
#                     'tot_rev_per_s': 83.82352941,
#                     'tot_spend_per_s': 67.29411765},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 3.0,
#                     'ave_prcnt_othr': 1.0,
#                     'ave_prcnt_wht': 91.0,
#                     'ave_school_enrol': 237.0,
#                     'district': 'Whiteford Agricultural School District of the '
#                                 'Counties of Lenawee and Monroe',
#                     'district_enrollment': 682,
#                     'fed_rev_per_s': 0.173020528,
#                     'lat': 41.767824,
#                     'lng': -83.703209,
#                     'loc_rev_per_s': 3.114369501,
#                     'prcnt_stdnts_eligible_for_frl': 25.0,
#                     'st_rev_per_s': 6.992668622,
#                     'tot_inst_per_s': 5.338709677,
#                     'tot_rev_per_s': 10.28005865,
#                     'tot_spend_per_s': 9.319648094},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 3.75,
#                     'ave_prcnt_othr': 2.5,
#                     'ave_prcnt_wht': 89.25,
#                     'ave_school_enrol': 503.5,
#                     'district': 'Whitehall District Schools',
#                     'district_enrollment': 2218,
#                     'fed_rev_per_s': 0.701983769,
#                     'lat': 43.39791545,
#                     'lng': -86.33635413,
#                     'loc_rev_per_s': 3.792155095,
#                     'prcnt_stdnts_eligible_for_frl': 46.25,
#                     'st_rev_per_s': 6.848512173,
#                     'tot_inst_per_s': 6.522091975,
#                     'tot_rev_per_s': 11.34265104,
#                     'tot_spend_per_s': 12.50586114},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 7.0,
#                     'ave_prcnt_wht': 89.0,
#                     'ave_school_enrol': 400.0,
#                     'district': 'Whitmore Lake Public School District',
#                     'district_enrollment': 854,
#                     'fed_rev_per_s': 0.570257611,
#                     'lat': 42.4057375,
#                     'lng': -83.77770985,
#                     'loc_rev_per_s': 9.033957845,
#                     'prcnt_stdnts_eligible_for_frl': 40.5,
#                     'st_rev_per_s': 6.844262295,
#                     'tot_inst_per_s': 6.011709602000001,
#                     'tot_rev_per_s': 16.44847775,
#                     'tot_spend_per_s': 14.15339578},
#                    {'ave_prcnt_asn': 0.0,
#                     'ave_prcnt_bk': 1.0,
#                     'ave_prcnt_othr': 3.0,
#                     'ave_prcnt_wht': 95.5,
#                     'ave_school_enrol': 426.0,
#                     'district': 'Whittemore-Prescott Area Schools',
#                     'district_enrollment': 838,
#                     'fed_rev_per_s': 1.38902148,
#                     'lat': 44.2280151,
#                     'lng': -83.88126595,
#                     'loc_rev_per_s': 3.599045346,
#                     'prcnt_stdnts_eligible_for_frl': 85.5,
#                     'st_rev_per_s': 6.454653938,
#                     'tot_inst_per_s': 5.737470167000001,
#                     'tot_rev_per_s': 11.44272076,
#                     'tot_spend_per_s': 10.23627685},
#                    {'ave_prcnt_asn': 1.5,
#                     'ave_prcnt_bk': 1.5,
#                     'ave_prcnt_othr': 3.5,
#                     'ave_prcnt_wht': 90.0,
#                     'ave_school_enrol': 445.5,
#                     'district': 'Williamston Community Schools',
#                     'district_enrollment': 1794,
#                     'fed_rev_per_s': 0.316053512,
#                     'lat': 42.69495928,
#                     'lng': -84.27506240000002,
#                     'loc_rev_per_s': 4.0958751389999986,
#                     'prcnt_stdnts_eligible_for_frl': 19.75,
#                     'st_rev_per_s': 7.855629877,
#                     'tot_inst_per_s': 6.356187291,
#                     'tot_rev_per_s': 12.26755853,
#                     'tot_spend_per_s': 11.30992196},
#                    {'ave_prcnt_asn': 1.0,
#                     'ave_prcnt_bk': 2.0,
#                     'ave_prcnt_othr': 9.0,
#                     'ave_prcnt_wht': 87.0,
#                     'ave_school_enrol': 149.0,
#                     'district': 'Wolverine Community School District',
#                     'district_enrollment': 272,
#                     'fed_rev_per_s': 1.323529412,
#                     'lat': 45.2717992,
#                     'lng': -84.6063743,
#                     'loc_rev_per_s': 4.691176471,
#                     'prcnt_stdnts_eligible_for_frl': 89.0,
#                     'st_rev_per_s': 6.330882353,
#                     'tot_inst_per_s': 7.963235293999999,
#                     'tot_rev_per_s': 12.34558824,
#                     'tot_spend_per_s': 12.20588235},
#                    {'ave_prcnt_asn': 5.375,
#                     'ave_prcnt_bk': 12.375,
#                     'ave_prcnt_othr': 3.5,
#                     'ave_prcnt_wht': 70.375,
#                     'ave_school_enrol': 483.5,
#                     'district': 'Woodhaven-Brownstown School District',
#                     'district_enrollment': 5215,
#                     'fed_rev_per_s': 0.403451582,
#                     'lat': 42.14109486,
#                     'lng': -83.25930024,
#                     'loc_rev_per_s': 3.792521572,
#                     'prcnt_stdnts_eligible_for_frl': 44.5,
#                     'st_rev_per_s': 7.340172579,
#                     'tot_inst_per_s': 6.295685523,
#                     'tot_rev_per_s': 11.53614573,
#                     'tot_spend_per_s': 10.92579099},
#                    {'ave_prcnt_asn': 0.5,
#                     'ave_prcnt_bk': 7.75,
#                     'ave_prcnt_othr': 2.75,
#                     'ave_prcnt_wht': 79.625,
#                     'ave_school_enrol': 532.375,
#                     'district': 'Wyandotte, School District of the City of',
#                     'district_enrollment': 4503,
#                     'fed_rev_per_s': 0.808572063,
#                     'lat': 42.20670315,
#                     'lng': -83.16631769,
#                     'loc_rev_per_s': 5.4645791689999985,
#                     'prcnt_stdnts_eligible_for_frl': 70.125,
#                     'st_rev_per_s': 8.698645348,
#                     'tot_inst_per_s': 7.863646458,
#                     'tot_rev_per_s': 14.97179658,
#                     'tot_spend_per_s': 18.07372863},
#                    {'ave_prcnt_asn': 2.142857143,
#                     'ave_prcnt_bk': 12.57142857,
#                     'ave_prcnt_othr': 8.428571429,
#                     'ave_prcnt_wht': 40.42857143,
#                     'ave_school_enrol': 479.5714286000001,
#                     'district': 'Wyoming Public Schools',
#                     'district_enrollment': 4437,
#                     'fed_rev_per_s': 1.284201037,
#                     'lat': 42.90617713,
#                     'lng': -85.7081342,
#                     'loc_rev_per_s': 3.819697994,
#                     'prcnt_stdnts_eligible_for_frl': 73.85714286,
#                     'st_rev_per_s': 7.276538201,
#                     'tot_inst_per_s': 6.46833446,
#                     'tot_rev_per_s': 12.38043723,
#                     'tot_spend_per_s': 11.26369168},
#                    {'ave_prcnt_asn': 0.2,
#                     'ave_prcnt_bk': 0.6,
#                     'ave_prcnt_othr': 2.0,
#                     'ave_prcnt_wht': 94.4,
#                     'ave_school_enrol': 379.8,
#                     'district': 'Yale Public Schools',
#                     'district_enrollment': 1946,
#                     'fed_rev_per_s': 0.402877698,
#                     'lat': 43.08656526,
#                     'lng': -82.77422568,
#                     'loc_rev_per_s': 3.2985611510000004,
#                     'prcnt_stdnts_eligible_for_frl': 43.2,
#                     'st_rev_per_s': 7.035971223,
#                     'tot_inst_per_s': 5.892086331000002,
#                     'tot_rev_per_s': 10.73741007,
#                     'tot_spend_per_s': 10.44501542},
#                    {'ave_prcnt_asn': 1.375,
#                     'ave_prcnt_bk': 62.875,
#                     'ave_prcnt_othr': 6.5,
#                     'ave_prcnt_wht': 21.75,
#                     'ave_school_enrol': 337.125,
#                     'district': 'Ypsilanti Community Schools',
#                     'district_enrollment': 3868,
#                     'fed_rev_per_s': 1.958893485,
#                     'lat': 42.24167493,
#                     'lng': -83.61013014,
#                     'loc_rev_per_s': 6.995863495,
#                     'prcnt_stdnts_eligible_for_frl': 82.625,
#                     'st_rev_per_s': 7.722595657,
#                     'tot_inst_per_s': 6.757238882999999,
#                     'tot_rev_per_s': 16.67735264,
#                     'tot_spend_per_s': 16.04058945},
#                    {'ave_prcnt_asn': 3.909090909,
#                     'ave_prcnt_bk': 1.363636364,
#                     'ave_prcnt_othr': 3.909090909,
#                     'ave_prcnt_wht': 76.18181818,
#                     'ave_school_enrol': 514.2727273,
#                     'district': 'Zeeland Public Schools',
#                     'district_enrollment': 5880,
#                     'fed_rev_per_s': 0.242857143,
#                     'lat': 42.81515759,
#                     'lng': -86.01882665,
#                     'loc_rev_per_s': 4.478061224,
#                     'prcnt_stdnts_eligible_for_frl': 29.63636364,
#                     'st_rev_per_s': 6.935884354,
#                     'tot_inst_per_s': 6.7022108839999985,
#                     'tot_rev_per_s': 11.65680272,
#                     'tot_spend_per_s': 13.06768707}]}
